# %% [markdown]
# Name: Atharv Deshmukh
#     Rollno: 21102B0053
#      BE CMPN B
#
# Experiment 8: DBSCAN on Mall Customer dataset
# Github: https://github.com/atharvdeshmukh07/ML-Practicals-Sem-7/blob/main/ML_Expt_8_DBSCAN_on_Mall_Customer_dataset.ipynb

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Mall_Customers.csv')

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
features = data[['Annual Income (k$)', 'Spending Score (1-100)']]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(scaled_features)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(features['Annual Income (k$)'], features['Spending Score (1-100)'], c=labels, cmap='plasma')
plt.title('DBSCAN Clustering of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
unique_clusters = len(set(labels)) - (1 if -1 in labels else 0)
noise_points = np.sum(labels == -1)

print(f"Number of clusters found: {unique_clusters}")
print(f"Number of noise points: {noise_points}")
# Out:
# Number of clusters found: 2
# Number of noise points: 8
